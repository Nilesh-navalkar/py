# %%
#pandas

# %%
import pandas as p
import xlrd   #for reading xlsheets

dataframe=p.read_excel("student.xlsx")

# %%
print(dataframe)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John    NaN    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
newdataframe=p.read_csv("student.csv")

# %%
print(newdataframe)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
import csv
file=open("student.csv")

csv_reader = csv.reader(file)
df=p.DataFrame(file)

# %%
print(df)
# Out:
#                                  0
# 0      id,name,class,mark,gender\n
# 1      1,John Deo,Four,75,female\n
# 2       2,Max Ruin,Three,85,male\n
# 3         3,Arnold,Three,55,male\n
# 4    4,Krish Star,Four,60,female\n
# 5     5,John Mike,Four,60,female\n
# 6       6,Alex John,Four,55,male\n
# 7    7,My John Rob,Fifth,78,male\n
# 8          8,Asruid,Five,85,male\n
# 9          9,Tes Qry,Six,78,male\n
# 10    10,Big John,Four,55,female\n
# 11       11,Ronald,Six,89,female\n
# 12        12,Recky,Six,94,female\n
# 13        13,Kty,Seven,88,female\n
# 14       14,Bigy,Seven,88,female\n
# 15      15,Tade Row,Four,88,male\n
# 16         16,Gimmy,Four,88,male\n
# 17          17,Tumyu,Six,54,male\n
# 18         18,Honny,Five,75,male\n
# 19         19,Tinny,Nine,18,male\n
# 20      20,Jackly,Nine,65,female\n
# 21  21,Babby John,Four,69,female\n
# 22     22,Reggid,Seven,55,female\n
# 23        23,Herod,Eight,79,male\n
# 24    24,Tiddy Now,Seven,78,male\n
# 25     25,Giff Tow,Seven,88,male\n
# ...

# %%
df.shape
# Out:
# (36, 1)

# %%
df.to_csv("student.csv")

# %%
print(df)
# Out:
#                                  0
# 0      id,name,class,mark,gender\n
# 1      1,John Deo,Four,75,female\n
# 2       2,Max Ruin,Three,85,male\n
# 3         3,Arnold,Three,55,male\n
# 4    4,Krish Star,Four,60,female\n
# 5     5,John Mike,Four,60,female\n
# 6       6,Alex John,Four,55,male\n
# 7    7,My John Rob,Fifth,78,male\n
# 8          8,Asruid,Five,85,male\n
# 9          9,Tes Qry,Six,78,male\n
# 10    10,Big John,Four,55,female\n
# 11       11,Ronald,Six,89,female\n
# 12        12,Recky,Six,94,female\n
# 13        13,Kty,Seven,88,female\n
# 14       14,Bigy,Seven,88,female\n
# 15      15,Tade Row,Four,88,male\n
# 16         16,Gimmy,Four,88,male\n
# 17          17,Tumyu,Six,54,male\n
# 18         18,Honny,Five,75,male\n
# 19         19,Tinny,Nine,18,male\n
# 20      20,Jackly,Nine,65,female\n
# 21  21,Babby John,Four,69,female\n
# 22     22,Reggid,Seven,55,female\n
# 23        23,Herod,Eight,79,male\n
# 24    24,Tiddy Now,Seven,78,male\n
# 25     25,Giff Tow,Seven,88,male\n
# ...

# %%
df.shape
# Out:
# (36, 1)

# %%
#df.head(n)  first n entries
#df.tail(n)  last n entries

#df.head()  #first 5 entries
df.tail()   #last 5 entries
# Out:
#                                  0
# 31   31,Marry Toeey,Four,88,male\n
# 32  32,Binn Rott,Seven,90,female\n
# 33    33,Kenn Rein,Six,96,female\n
# 34     34,Gain Toe,Seven,69,male\n
# 35   35,Rows Noump,Six,88,female\n

# %%
df[2:5]  #slicing
# Out:
#                                0
# 2     2,Max Ruin,Three,85,male\n
# 3       3,Arnold,Three,55,male\n
# 4  4,Krish Star,Four,60,female\n

# %%
df[::-1]  #reverse dataframe
# Out:
#                                  0
# 35   35,Rows Noump,Six,88,female\n
# 34     34,Gain Toe,Seven,69,male\n
# 33    33,Kenn Rein,Six,96,female\n
# 32  32,Binn Rott,Seven,90,female\n
# 31   31,Marry Toeey,Four,88,male\n
# 30    30,Reppy Red,Six,79,female\n
# 29  29,Tess Played,Seven,55,male\n
# 28  28,Rojj Base,Seven,86,female\n
# 27   27,Big Nose,Three,81,female\n
# 26       26,Crelea,Seven,79,male\n
# 25     25,Giff Tow,Seven,88,male\n
# 24    24,Tiddy Now,Seven,78,male\n
# 23        23,Herod,Eight,79,male\n
# 22     22,Reggid,Seven,55,female\n
# 21  21,Babby John,Four,69,female\n
# 20      20,Jackly,Nine,65,female\n
# 19         19,Tinny,Nine,18,male\n
# 18         18,Honny,Five,75,male\n
# 17          17,Tumyu,Six,54,male\n
# 16         16,Gimmy,Four,88,male\n
# 15      15,Tade Row,Four,88,male\n
# 14       14,Bigy,Seven,88,female\n
# 13        13,Kty,Seven,88,female\n
# 12        12,Recky,Six,94,female\n
# 11       11,Ronald,Six,89,female\n
# 10    10,Big John,Four,55,female\n
# ...

# %%
df[::2] #alternate
# Out:
#                                  0
# 0      id,name,class,mark,gender\n
# 2       2,Max Ruin,Three,85,male\n
# 4    4,Krish Star,Four,60,female\n
# 6       6,Alex John,Four,55,male\n
# 8          8,Asruid,Five,85,male\n
# 10    10,Big John,Four,55,female\n
# 12        12,Recky,Six,94,female\n
# 14       14,Bigy,Seven,88,female\n
# 16         16,Gimmy,Four,88,male\n
# 18         18,Honny,Five,75,male\n
# 20      20,Jackly,Nine,65,female\n
# 22     22,Reggid,Seven,55,female\n
# 24    24,Tiddy Now,Seven,78,male\n
# 26       26,Crelea,Seven,79,male\n
# 28  28,Rojj Base,Seven,86,female\n
# 30    30,Reppy Red,Six,79,female\n
# 32  32,Binn Rott,Seven,90,female\n
# 34     34,Gain Toe,Seven,69,male\n

# %%
df.columns
dataframe.columns
#df.columnname gives particular column
#df[['colname1']['colname2']] more than 1 col
#.min(),.max()
#df['colname1'].min()/.max()  gives min/max of columnname1
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
#df.describe()
dataframe.describe()
#gives mean count max min 50% 75%
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
#df[df.mark>74] gives people with marks greater than 75

dataframe[dataframe.mark>74]
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 17  18        Honny   Five    75    male
# 22  23        Herod  Eight    79    male
# 23  24    Tiddy Now  Seven    78    male
# 24  25     Giff Tow    Six    88    male
# 25  26       Crelea  Seven    79    male
# 26  27     Big Nose  Three    81  female
# 27  28    Rojj Base  Seven    86  female
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# ...

# %%
#df(df.mark==df.mark.max()) all people who got max marks
dataframe[dataframe.mark==dataframe.mark.max()]
# Out:
#     id       name class  mark  gender
# 32  33  Kenn Rein   Six    96  female

# %%
dataframe[['name','gender']][dataframe.mark>74]  
#name and gender of studs who got marks greater than 74
# Out:
#            name  gender
# 0      John Deo  female
# 1      Max Ruin    male
# 6   My John Rob    male
# 7        Asruid    male
# 8       Tes Qry    male
# 10       Ronald  female
# 11        Recky  female
# 12          Kty  female
# 13         Bigy  female
# 14     Tade Row    male
# 15        Gimmy    male
# 17        Honny    male
# 22        Herod    male
# 23    Tiddy Now    male
# 24     Giff Tow    male
# 25       Crelea    male
# 26     Big Nose  female
# 27    Rojj Base  female
# 29    Reppy Red  female
# 30  Marry Toeey    male
# 31    Binn Rott  female
# 32    Kenn Rein  female
# 34   Rows Noump  female

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=35, step=1)

# %%
df1=dataframe.set_index("id")
#remove the id field and copying the view in new df

# %%
print(df1)
# Out:
#            name  class  mark  gender
# id
# 1      John Deo   Four    75  female
# 2      Max Ruin  Three    85    male
# 3        Arnold  Three    55    male
# 4    Krish Star   Four    60  female
# 5     John Mike   Four    60  female
# 6     Alex John   Four    55    male
# 7   My John Rob   Five    78    male
# 8        Asruid   Five    85    male
# 9       Tes Qry    Six    78    male
# 10     Big John    NaN    55  female
# 11       Ronald    Six    89  female
# 12        Recky    Six    94  female
# 13          Kty  Seven    88  female
# 14         Bigy  Seven    88  female
# 15     Tade Row   Four    88    male
# 16        Gimmy   Four    88    male
# 17        Tumyu    Six    54    male
# 18        Honny   Five    75    male
# 19        Tinny   Nine    18    male
# 20       Jackly   Nine    65  female
# 21   Babby John   Four    69  female
# 22       Reggid  Seven    55  female
# 23        Herod  Eight    79    male
# 24    Tiddy Now  Seven    78    male
# ...

# %%
df1.reset_index()
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John    NaN    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
dataframe.loc[22]
#locate a particular data
# Out:
# id           23
# name      Herod
# class     Eight
# mark         79
# gender     male
# Name: 22, dtype: object

# %%
df2=dataframe.sort_values('mark')

# %%
df2=dataframe.sort_values(by=['mark'],ascending=[False])

# %%
print(df2)
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 24  25     Giff Tow    Six    88    male
# 15  16        Gimmy   Four    88    male
# 14  15     Tade Row   Four    88    male
# 13  14         Bigy  Seven    88  female
# 12  13          Kty  Seven    88  female
# 34  35   Rows Noump    Six    88  female
# 30  31  Marry Toeey   Four    88    male
# 27  28    Rojj Base  Seven    86  female
# 7    8       Asruid   Five    85    male
# 1    2     Max Ruin  Three    85    male
# 26  27     Big Nose  Three    81  female
# 22  23        Herod  Eight    79    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 8    9      Tes Qry    Six    78    male
# 6    7  My John Rob   Five    78    male
# 23  24    Tiddy Now  Seven    78    male
# 0    1     John Deo   Four    75  female
# ...

# %%
df2=dataframe.sort_values(by=['mark','gender'])

# %%
print(df2)
# Out:
#     id         name  class  mark  gender
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 9   10     Big John    NaN    55  female
# 21  22       Reggid  Seven    55  female
# 2    3       Arnold  Three    55    male
# 5    6    Alex John   Four    55    male
# 28  29  Tess Played  Seven    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 0    1     John Deo   Four    75  female
# 17  18        Honny   Five    75    male
# 6    7  My John Rob   Five    78    male
# 8    9      Tes Qry    Six    78    male
# 23  24    Tiddy Now  Seven    78    male
# 29  30    Reppy Red    Six    79  female
# 22  23        Herod  Eight    79    male
# 25  26       Crelea  Seven    79    male
# 26  27     Big Nose  Three    81  female
# 1    2     Max Ruin  Three    85    male
# ...

# %%
ndf=p.read_excel("student.xlsx")

# %%
print(ndf)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin    NaN    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid    NaN    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John    NaN    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
ndf=dataframe.fillna(0)

# %%
print(ndf)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John      0    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...
